# %% [markdown]
# #### Figure 2C
# The result (Mean-F1) of running src/ewcsn_classify_test.py in different hvgs(1000, 2000, 3000, 5000, 10000, all)

# %%
# F1-score

import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"

# Data
muraro_scores = [0.957, 0.964, 0.967, 0.961, 0.958, 0.964]
baron_mouse_scores = [0.933, 0.969, 0.941, 0.935, 0.843, 0.868]
hvgs = ["1000", "2000", "3000", "5000", "10000", "All"]

# Create a line plot
plt.figure(figsize=(4, 3))
plt.plot(range(1, len(muraro_scores) + 1), muraro_scores, label="Muraro", marker='o', linestyle='-', markersize=4)
plt.plot(range(1, len(baron_mouse_scores) + 1), baron_mouse_scores, label="Baron Mouse", marker='s', linestyle='--', markersize=4)


# Customize x-axis ticks
plt.xticks(range(1, len(hvgs) + 1), hvgs, fontsize=10)

# Add labels and legend
plt.xlabel("Number of Highly Variable Genes (HVGs)", fontweight="bold", fontsize=10)
plt.ylabel("Mean F1", fontweight="bold", fontsize=10)
plt.ylim(0.6, 1.0)  # Set y-axis range
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
# Show plot
plt.tight_layout()
plt.savefig('../../result/Figures/Figure_2C.svg', format='svg', dpi=1200, bbox_inches='tight')
plt.savefig('../../result/Figures/Figure_2C.png', format='png', dpi=1200, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Figure 2D
# The result (Accuracy) of running src/ewcsn_classify_test.py in different hvgs(1000, 2000, 3000, 5000, 10000, all)

# %%
# accuracy

import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Times New Roman"

muraro_scores = [0.965, 0.973,	0.975,	0.973,	0.969,	0.971]
baron_mouse_scores = [0.954, 0.981, 0.975, 0.966,	0.922,	0.939]

hvgs = ["1000", "2000", "3000", "5000", "10000", "All"]

# Create a line plot
plt.figure(figsize=(4, 3))
plt.plot(range(1, len(muraro_scores) + 1), muraro_scores, label="Muraro", marker='o', linestyle='-', markersize=4)
plt.plot(range(1, len(baron_mouse_scores) + 1), baron_mouse_scores, label="Baron Mouse", marker='s', linestyle='--', markersize=4)


# Customize x-axis ticks
plt.xticks(range(1, len(hvgs) + 1), hvgs, fontsize=10)

# Add labels and legend
plt.xlabel("Number of Highly Variable Genes (HVGs)", fontweight="bold", fontsize=10)
plt.ylabel("Mean F1", fontweight="bold", fontsize=10)
plt.ylim(0.6, 1.0)  # Set y-axis range
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

# Show plot
plt.tight_layout()

plt.savefig('../../result/Figures/Figure_2D.svg', format='svg', dpi=1200, bbox_inches='tight')
plt.savefig('../../result/Figures/Figure_2D.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()
