# %% [markdown]
# #### Sankey: Zheng 68k

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pySankey.sankey import sankey

from matplotlib import rcParams
rcParams['font.family'] = 'Times New Roman'

def plot_cell_type_sankey(seq_dict_file, pred_file, figure_size=(24, 16), dpi=1200):
    try:
        seq_dict = np.load(seq_dict_file, allow_pickle=True)
        str_labels = seq_dict['str_labels']
    except Exception as e:
        raise Exception(f"load cell type label error: {e}")
        
    try:
        cell_type = pd.read_hdf(pred_file, key='cell_type')
    except Exception as e:
        raise Exception(f"load pred file error: {e}")

    true_labels = cell_type['true_cell_type'].values
    pred_labels = cell_type['pred_cell_type'].values
    
    true_label = [str_labels[label] for label in true_labels]
    pred_label = [str_labels[label] for label in pred_labels]

    color_dict = {
        'alpha': '#c2e6c2',          
        'beta': '#b5e2e2',           
        'ductal': '#f2d4d4',         
        'delta': '#d4e2f2',         
        'gamma': '#c2e6c2',          
        'activated_stellate': '#e6e3c2', 
        'acinar': '#d4d4d4',         
        'endothelial': '#f2d4e6',    
        'macrophage': '#e6d4c2',    
        'epsilon': '#e6e6e6',        
        'quiescent_stellate': '#f2f2f2', 
        'schwann': '#BAD8FB',       
        'mast': '#FBE5B8',         
    }

    plt.figure(figsize=figure_size, dpi=dpi)
    
    plt.rcParams.update({
        'font.family': 'Times New Roman',
        'font.weight': 'normal',
        'font.size': 10,
        'axes.labelweight': 'normal',
        'axes.titleweight': 'normal'
    })
    
    try:
        sankey(
            right=true_label,    
            left=pred_label,      
            colorDict=color_dict, 
            aspect=15,            
            fontsize=8,           
            figure_name=plt.gcf()
        )
    except Exception as e:
        raise Exception(f"Sankey error: {e}")
    
    for text in plt.gca().texts:
        text.set_fontname('Times New Roman')

    plt.subplots_adjust(left=0.25, right=0.75, top=0.9, bottom=0.1)  

    for i, text in enumerate(plt.gca().texts):
        if i < len(true_label):  
            text.set_position((text.get_position()[0] - 0.05, text.get_position()[1])) 
        else: 
            text.set_position((text.get_position()[0] + 0.05, text.get_position()[1])) 


    plt.savefig("../../result/Figures/Figure_2A.svg", format="svg", dpi=dpi)
    plt.savefig("../../result/Figures/Figure_2A.svg", format="png", dpi=dpi)
    plt.show()


seq_dict_file = '../../dataset/5fold_data/Zheng68K/seq_dict.npz'
pred_path = '../../result/preds/Zheng68K_a0.01_hvgs2000_prediction.h5'

plot_cell_type_sankey(seq_dict_file, pred_path)

# %% [markdown]
# #### Sankey: Baron Human

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pySankey.sankey import sankey

from matplotlib import rcParams
rcParams['font.family'] = 'Times New Roman'

def plot_cell_type_sankey(seq_dict_file, pred_file, figure_size=(24, 16), dpi=1200):
    try:
        seq_dict = np.load(seq_dict_file, allow_pickle=True)
        str_labels = seq_dict['str_labels']
    except Exception as e:
        raise Exception(f"load cell type label error: {e}")
        
    try:
        cell_type = pd.read_hdf(pred_file, key='cell_type')
    except Exception as e:
        raise Exception(f"load pred file error: {e}")

    true_labels = cell_type['true_cell_type'].values
    pred_labels = cell_type['pred_cell_type'].values
    
    true_label = [str_labels[label] for label in true_labels]
    pred_label = [str_labels[label] for label in pred_labels]

    color_dict = {
        'alpha': '#c2e6c2',          
        'beta': '#b5e2e2',           
        'ductal': '#f2d4d4',         
        'delta': '#d4e2f2',         
        'gamma': '#c2e6c2',          
        'activated_stellate': '#e6e3c2', 
        'acinar': '#d4d4d4',         
        'endothelial': '#f2d4e6',    
        'macrophage': '#e6d4c2',    
        'epsilon': '#e6e6e6',        
        'quiescent_stellate': '#f2f2f2', 
        'schwann': '#BAD8FB',       
        'mast': '#FBE5B8',         
    }

    plt.figure(figsize=figure_size, dpi=dpi)
    
    plt.rcParams.update({
        'font.family': 'Times New Roman',
        'font.weight': 'normal',
        'font.size': 10,
        'axes.labelweight': 'normal',
        'axes.titleweight': 'normal'
    })
    
    try:
        sankey(
            right=true_label,    
            left=pred_label,      
            colorDict=color_dict, 
            aspect=15,            
            fontsize=8,           
            figure_name=plt.gcf()
        )
    except Exception as e:
        raise Exception(f"Sankey error: {e}")
    
    for text in plt.gca().texts:
        text.set_fontname('Times New Roman')

    plt.subplots_adjust(left=0.25, right=0.75, top=0.9, bottom=0.1)  

    for i, text in enumerate(plt.gca().texts):
        if i < len(true_label):  
            text.set_position((text.get_position()[0] - 0.05, text.get_position()[1])) 
        else: 
            text.set_position((text.get_position()[0] + 0.05, text.get_position()[1])) 


    plt.savefig("../../result/Figures/Figure_2B.svg", format="svg", dpi=dpi)
    plt.savefig("../../result/Figures/Figure_2B.png", format="png", dpi=dpi)
    plt.show()


seq_dict_file = '../../dataset/5fold_data/Baron_Human/seq_dict.npz'
pred_path = '../../result/preds/Baron_Human_a0.01_hvgs2000_prediction.h5'

plot_cell_type_sankey(seq_dict_file, pred_path)

# %% [markdown]
# #### Sankey: Segerstolpe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pySankey.sankey import sankey

from matplotlib import rcParams
rcParams['font.family'] = 'Times New Roman'

def plot_cell_type_sankey(seq_dict_file, pred_file, figure_size=(24, 16), dpi=1200):
    try:
        seq_dict = np.load(seq_dict_file, allow_pickle=True)
        str_labels = seq_dict['str_labels']
    except Exception as e:
        raise Exception(f"load cell type label error: {e}")
        
    try:
        cell_type = pd.read_hdf(pred_file, key='cell_type')
    except Exception as e:
        raise Exception(f"load pred file error: {e}")

    true_labels = cell_type['true_cell_type'].values
    pred_labels = cell_type['pred_cell_type'].values
    
    true_label = [str_labels[label] for label in true_labels]
    pred_label = [str_labels[label] for label in pred_labels]

    color_dict = {
        'alpha': '#c2e6c2',          
        'beta': '#b5e2e2',           
        'ductal': '#f2d4d4',         
        'delta': '#d4e2f2',         
        'gamma': '#c2e6c2',          
        'activated_stellate': '#e6e3c2', 
        'acinar': '#d4d4d4',         
        'endothelial': '#f2d4e6',    
        'macrophage': '#e6d4c2',    
        'epsilon': '#e6e6e6',        
        'quiescent_stellate': '#f2f2f2', 
        'schwann': '#BAD8FB',       
        'mast': '#FBE5B8',         
    }

    plt.figure(figsize=figure_size, dpi=dpi)
    
    plt.rcParams.update({
        'font.family': 'Times New Roman',
        'font.weight': 'normal',
        'font.size': 10,
        'axes.labelweight': 'normal',
        'axes.titleweight': 'normal'
    })
    
    try:
        sankey(
            right=true_label,    
            left=pred_label,      
            colorDict=color_dict, 
            aspect=15,            
            fontsize=8,           
            figure_name=plt.gcf()
        )
    except Exception as e:
        raise Exception(f"Sankey error: {e}")
    
    for text in plt.gca().texts:
        text.set_fontname('Times New Roman')

    plt.subplots_adjust(left=0.25, right=0.75, top=0.9, bottom=0.1)  

    for i, text in enumerate(plt.gca().texts):
        if i < len(true_label):  
            text.set_position((text.get_position()[0] - 0.05, text.get_position()[1])) 
        else: 
            text.set_position((text.get_position()[0] + 0.05, text.get_position()[1])) 


    plt.savefig("../../result/Figures/Figure_2C.svg", format="svg", dpi=dpi)
    plt.savefig("../../result/Figures/Figure_2C.png", format="png", dpi=dpi)
    plt.show()


seq_dict_file = '../../dataset/5fold_data/Segerstolpe/seq_dict.npz'
pred_path = '../../result/preds/Segerstolpe_a0.01_hvgs2000_prediction.h5'

plot_cell_type_sankey(seq_dict_file, pred_path)

# %% [markdown]
# #### Sankey: AMB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pySankey.sankey import sankey

from matplotlib import rcParams
rcParams['font.family'] = 'Times New Roman'

def plot_cell_type_sankey(seq_dict_file, pred_file, figure_size=(24, 16), dpi=1200):
    try:
        seq_dict = np.load(seq_dict_file, allow_pickle=True)
        str_labels = seq_dict['str_labels']
    except Exception as e:
        raise Exception(f"load cell type label error: {e}")
        
    try:
        cell_type = pd.read_hdf(pred_file, key='cell_type')
    except Exception as e:
        raise Exception(f"load pred file error: {e}")

    true_labels = cell_type['true_cell_type'].values
    pred_labels = cell_type['pred_cell_type'].values
    
    true_label = [str_labels[label] for label in true_labels]
    pred_label = [str_labels[label] for label in pred_labels]

    color_dict = {
        'alpha': '#c2e6c2',          
        'beta': '#b5e2e2',           
        'ductal': '#f2d4d4',         
        'delta': '#d4e2f2',         
        'gamma': '#c2e6c2',          
        'activated_stellate': '#e6e3c2', 
        'acinar': '#d4d4d4',         
        'endothelial': '#f2d4e6',    
        'macrophage': '#e6d4c2',    
        'epsilon': '#e6e6e6',        
        'quiescent_stellate': '#f2f2f2', 
        'schwann': '#BAD8FB',       
        'mast': '#FBE5B8',         
    }

    plt.figure(figsize=figure_size, dpi=dpi)
    
    plt.rcParams.update({
        'font.family': 'Times New Roman',
        'font.weight': 'normal',
        'font.size': 10,
        'axes.labelweight': 'normal',
        'axes.titleweight': 'normal'
    })
    
    try:
        sankey(
            right=true_label,    
            left=pred_label,      
            colorDict=color_dict, 
            aspect=15,            
            fontsize=8,           
            figure_name=plt.gcf()
        )
    except Exception as e:
        raise Exception(f"Sankey error: {e}")
    
    for text in plt.gca().texts:
        text.set_fontname('Times New Roman')

    plt.subplots_adjust(left=0.25, right=0.75, top=0.9, bottom=0.1)  

    for i, text in enumerate(plt.gca().texts):
        if i < len(true_label):  
            text.set_position((text.get_position()[0] - 0.05, text.get_position()[1])) 
        else: 
            text.set_position((text.get_position()[0] + 0.05, text.get_position()[1])) 


    plt.savefig("../../result/Figures/Figure_2D.svg", format="svg", dpi=dpi)
    plt.savefig("../../result/Figures/Figure_2D.png", format="png", dpi=dpi)
    plt.show()


seq_dict_file = '../../dataset/5fold_data/AMB/seq_dict.npz'
pred_path = '../../result/preds/AMB_a0.01_hvgs2000_prediction.h5'

plot_cell_type_sankey(seq_dict_file, pred_path)
