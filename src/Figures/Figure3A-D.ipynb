# %% [markdown]
# #### Figure 3A
# datasets: Zhang T ,	Muraro, Segerstolpe , AMB, TM \
# src/ewcsn_classify_test.py \
# src/wcsn_classify_test.py

# %%
# Mean-F1 score

import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"] = "Times New Roman"

WCSGNet = [0.772,  0.964, 0.992, 1.000, 0.929]
WCSGNet_no_net = [0.768 ,0.966 ,0.993 ,	1.000 ,	0.927]

x = np.arange(len(WCSGNet))
width = 0.25

plt.figure(figsize=(4, 3))

plt.bar(x - width, WCSGNet, width, label='WCSGNet-EWCSN', color='#72B6A1',edgecolor='white', linewidth=1)
plt.bar(x, WCSGNet_no_net, width, label='WCSGNet-WCSN', color='#E99675',edgecolor='white', linewidth=1)

plt.ylabel('Mean F1',fontsize=10, fontweight="bold")
datasets = ["Zhang T",	"Muraro", "Segerstolpe" , "AMB", "TM"]
plt.xticks(x, [ dataset for dataset in datasets], fontsize=10)
plt.ylim(0.7, 1.0) 

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fontsize=10, ncol=2, frameon=False)

def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()

bars = plt.gca().patches
add_value_labels(bars)
plt.tight_layout()

plt.savefig('../../result/Figures/Figure_3A.svg', format='svg', dpi=1200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Figure 3B
# datasets: Zhang T ,	Muraro, Segerstolpe , AMB, TM \
# src/ewcsn_classify_test.py \
# src/wcsn_classify_test.py

# %%
# Accuracy

import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"] = "Times New Roman"

WCSGNet = [0.825, 0.973 , 0.994 , 1.000, 0.958 ]
WCSGNet_WCSN = [0.822 , 0.973 ,0.994 , 1.000 ,0.957]

x = np.arange(len(WCSGNet))
width = 0.3

plt.figure(figsize=(4, 3))

plt.bar(x - width, WCSGNet, width, label='WCSGNet-EWCSN', color='#72B6A1',edgecolor='white', linewidth=1)
plt.bar(x, WCSGNet_WCSN, width, label='WCSGNet-WCSN', color='#E99675',edgecolor='white', linewidth=1)

plt.ylabel('Accuracy',fontsize=10, fontweight="bold")
datasets = ["Zhang T",	"Muraro", "Segerstolpe" , "AMB", "TM"]
plt.xticks(x, [ dataset for dataset in datasets], fontsize=10)
plt.ylim(0.7, 1.0)  

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fontsize=10, ncol=2, frameon=False)

def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()

bars = plt.gca().patches
add_value_labels(bars)

plt.tight_layout()

plt.savefig('../../result/Figures/Figure_3B.svg', format='svg', dpi=1200, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Figure 3C
# run src/ewcsn_classify_train.py, src/ewcsn_classify_test.py using different high-confidence gene interaction data  \
# Mean-F1

# %%
# Mean-F1 score

import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"

WCSGNet_GSP = [0.772, 0.861, 0.693, 0.975, 0.964, 0.992]  
WCSGNet_ARG = [0.764, 0.862, 0.691, 0.974, 0.967, 0.993, 1.000, 0.929, 0.969]  
WCSGNet_BIOGRID = [0.779, 0.861, 0.690, 0.971, 0.964, 0.990, 1.000, 0.928, 0.965]  

datasets = ["Zhang T", "Kang", "Zheng 68k", "Baron Human", "Muraro", "Segerstolpe", "AMB", "TM", "Baron Mouse"]
WCSGNet_GSP = WCSGNet_GSP + [np.nan] * (len(datasets) - len(WCSGNet_GSP))


x = np.arange(len(datasets))  
width = 0.25  


plt.figure(figsize=(8, 4))
plt.bar(x - width, WCSGNet_GSP, width, label='WCSGNet(HumanNet-GSP)', color='#72B6A1', edgecolor='white', linewidth=1)
plt.bar(x, WCSGNet_ARG, width, label='WCSGNet(ARG)', color='#E99675', edgecolor='white', linewidth=1)
plt.bar(x + width, WCSGNet_BIOGRID, width, label='WCSGNet(BIOGRID)', color='#95A3C3', edgecolor='white', linewidth=1)

plt.ylabel('Mean F1', fontsize=10, fontweight="bold")
plt.xticks(x, datasets, fontsize=10, rotation=45) 
plt.ylim(0.6, 1.0) 


plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fontsize=10, ncol=3, frameon=False)

def add_value_labels(ax):
    for bar in ax.patches:
        height = bar.get_height()


ax = plt.gca()
add_value_labels(ax)

plt.tight_layout()

plt.savefig('../result/Figures/Figure_3C.svg', format='svg', dpi=1200, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Figure 4D
# run src/ewcsn_classify_train.py, src/ewcsn_classify_test.py using different high-confidence gene interaction data  \
# Accuracy

# %%
# Accuracy

import matplotlib.pyplot as plt
import numpy as np

WCSGNet_GSP = [0.825 ,0.939 ,0.761,	0.986 ,	0.973 ,	0.994 ]  
WCSGNet_ARG = [0.820 ,	0.939, 	0.761 ,	0.987 ,	0.971 ,	0.994 ,	1.000 ,	0.958 ,	0.981 ]  
WCSGNet_BIOGRID = [0.827 ,	0.938 ,	0.761 ,	0.986 ,	0.972, 	0.996 ,	1.000 ,	0.958 ,	0.980 ] 

datasets = ["Zhang T", "Kang", "Zheng 68k", "Baron Human", "Muraro", "Segerstolpe", "AMB", "TM", "Baron Mouse"]


WCSGNet_GSP = WCSGNet_GSP + [np.nan] * (len(datasets) - len(WCSGNet_GSP))

x = np.arange(len(datasets))  
width = 0.25  

plt.figure(figsize=(8, 4))

plt.bar(x - width, WCSGNet_GSP, width, label='WCSGNet(HumanNet-GSP)', color='#72B6A1', edgecolor='white', linewidth=1)
plt.bar(x, WCSGNet_ARG, width, label='WCSGNet(ARG)', color='#E99675', edgecolor='white', linewidth=1)
plt.bar(x + width, WCSGNet_BIOGRID, width, label='WCSGNet(BIOGRID)', color='#95A3C3', edgecolor='white', linewidth=1)

plt.ylabel('Accuracy', fontsize=10, fontweight="bold")
plt.xticks(x, datasets, fontsize=10, rotation=45)
plt.ylim(0.6, 1.0)  
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fontsize=10, ncol=3, frameon=False)

def add_value_labels(ax):
    for bar in ax.patches:
        height = bar.get_height()

ax = plt.gca()
add_value_labels(ax)

plt.tight_layout()

plt.savefig('../../result/Figures/Figure_3D.svg', format='svg', dpi=1200, bbox_inches='tight')
plt.show()
